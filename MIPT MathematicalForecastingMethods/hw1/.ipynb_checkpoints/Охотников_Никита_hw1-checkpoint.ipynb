# %% [markdown]
# #Домашнее задание 1. Классические линейные модели.
# В данном ноутбуке будут приведены примеры построения моделей из лекций 1 и 2, после чего предлагается воспроизвести процедуру настройки моделей на других временных рядах.

# %%
#!pip install -q arch pmdarima

# %%
#!pip pip

# %%
import os
import sys

import numpy as np
import pandas as pd
import pandas_datareader.data as web

import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.formula.api as smf

import scipy.stats as scs
from arch import arch_model

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %% [markdown]
# ## Модель SARIMA
# - Seasonal ARIMA = SARIMA
# $$ \text{SARIMA}(p, d, q)(P, D, Q)_S $$
#     - Базовые компоненты
#         - p: autoregressive order
#         - d: differencing order
#         - q: moving average order
#     - Сезонные компоненты
#         - P: seasonal autoregressive order
#         - D: seasonal differencing order
#         - Q: seasonal moving average order
#         - S: длина сезона
# - Примеры моделей ARIMA и SARIMA
#     - ARIMA(2, 0, 1):
# $$ x_t = a_1 x_{t-1} + a_2 x_{t-2} + m_1 \epsilon_{t-1} + \epsilon_t $$
#     - SARIMA(0,0,0)(2, 0, 1)_7:
# $$ x_t = a_7 x_{t-7} + a_{14} x_{t-14} + m_y \epsilon_{t-7} + \epsilon_t $$
#
# - Сезонное дифференцирование
#     - Вычитание из текущего значения его значения, соответствующего прошлому сезону
# $$ \Delta x_t = x_t - x_{t-S} $$

# %% [markdown]
# ## Исследуемый временной ряд
# Сгенерируем искусственный временной ряд с трендом, сезонной компонентой и шумом.

# %%
N = 700
trend = np.linspace(0, 2, N)**3
season = 1.5*np.sin(2*np.pi/(4*12) * np.arange(N))
wn = np.random.normal(loc=0.0, scale=0.5, size=N)
heteroskedastic = np.linspace(1, 2, N)
ts = trend + heteroskedastic*season + wn

# %%
fig, axs = plt.subplots(5, 1, figsize = (15,11))
axs[0].plot(trend)
axs[0].set_title('trend')
axs[1].plot(season)
axs[1].set_title('season')
axs[2].plot(wn)
axs[2].set_title('white noise')
axs[3].plot(heteroskedastic)
axs[3].set_title('heteroskedastic')
axs[4].plot(ts)
axs[4].set_title('Time series')
#plt.legend()
plt.show()

# %% [markdown]
# ## Последовательность действия для построения ARIMA модели
# 1. Строится график ряда, идентифицируются необычные значения.
# 2. Если ряд сильно нестационарный подбирается порядок дифференцирования.
#   - Рекомендуется сначала выбрать поряд сезонного дифференцирования, потом обычного дифференцирования.
#
# 4. Анализируются ACF/[PACF](http://www.machinelearning.ru/wiki/index.php?title=%D0%A7%D0%B0%D1%81%D1%82%D0%B8%D1%87%D0%BD%D0%B0%D1%8F_%D0%B0%D0%B2%D1%82%D0%BE%D0%BA%D0%BE%D1%80%D1%80%D0%B5%D0%BB%D1%8F%D1%86%D0%B8%D1%8F
# ), чтобы выбрать начальные приближения для параметров.
#   - p - последний значимый несезонный лаг (меньше сезонного периода) по [PACF](http://www.machinelearning.ru/wiki/index.php?title=%D0%A7%D0%B0%D1%81%D1%82%D0%B8%D1%87%D0%BD%D0%B0%D1%8F_%D0%B0%D0%B2%D1%82%D0%BE%D0%BA%D0%BE%D1%80%D1%80%D0%B5%D0%BB%D1%8F%D1%86%D0%B8%D1%8F
# )
#   - q - последний значимый несезонный лаг (меньше сезонного периода) по ACF
#   - P - последний значимый сезонный лаг по [PACF](http://www.machinelearning.ru/wiki/index.php?title=%D0%A7%D0%B0%D1%81%D1%82%D0%B8%D1%87%D0%BD%D0%B0%D1%8F_%D0%B0%D0%B2%D1%82%D0%BE%D0%BA%D0%BE%D1%80%D1%80%D0%B5%D0%BB%D1%8F%D1%86%D0%B8%D1%8F
# )
#   - Q - последний значимый сезонный лаг по ACF
# 5. Обучаются модели-кандидаты, в окрестностях начального приближения, сравнивается их AIC/BIC.
# 6. Остатки полученной модели исследуются на несмещённость, стационарность и неавтокоррелированность; если предположения невыполняются,исследуются модификациимодели.
#
# ___
# "Лаг" - величина сдвига в ACF/PACF; значимость лага - выход значения за пределы доверительного интервала, центрированного в нуле (см. комментарий ниже)
# ___

# %% [markdown]
# При обучении моделей SARIMAX одновременное нахождение оптимальных значений (p, q, d, P, Q, D) является возможным (см. pmdarima.auto_arima), но даже в таком случае удобно определить начальные значения параметров на основе анализа автокорреляционной функции ряда.
#
# Конкретно, методы statsmodels.tsa.api.plot_acf и statsmodels.tsa.api.plot_pacf позволяют построить автокорреляционную (ACF) и частичную автокорреляционную (PACF) функции ряда, а также построить для их значений доверительные интервалы. Доверительные интервалы на этих графиках отображаются на фоне в виде сплошной области, симметричной относительно оси абсцисс.
#
# По графикам этих функций определяются последние моменты времени, когда их значения существенно отличаются от нуля (т.е. не попадают в доверительный интервал). Эти значения, делённые нацело на подобранное значение сезонного периода S, и равны P и Q для PACF и ACF соответственно.
#
# Далее осуществляется дифференцирование ряда (обычное и сезонное), порядки дифференцирования определяются вручную. Наконец, для нового преобразованного ряда вновь строим ACF и PACF и по самым последним их значениям, выходящим за пределы доверительного интервала, определяем q и p соответственно. Ниже приведен пример.

# %% [markdown]
# ## Графики автокорреляционной функции

# %% [markdown]
# Нужно использовать ACF и PACF для проверки сезонности данных.
# Из графика выше видно, что временной ряд не является стационарным, поэтому, вероятно, следует исключить из него тренд.
# Удалить тренд можно либо с помощью вычитания тренда напрямую, либо использовать дифференцирование временного ряда.

# %%
fig, axs = plt.subplots(3, 2, figsize = (11,11))
axs[0, 0].remove()
axs[0, 1].remove()

gs = axs[0, 0].get_gridspec()
axbig = fig.add_subplot(gs[0, :2])
axbig.plot(ts)
axbig.set_title('Time series')

smt.graphics.plot_acf(ts, lags=300, ax=axs[1,0], alpha=0.05)
smt.graphics.plot_pacf(ts, lags=300, ax=axs[2,0], alpha=0.05)

smt.graphics.plot_acf(ts, lags=50, ax=axs[1,1], alpha=0.05)
smt.graphics.plot_pacf(ts, lags=50, ax=axs[2,1], alpha=0.05)
plt.show()

# %% [markdown]
# Выводы:
# 1. Есть тренд - используем дифференцирование d = 1, D = 1.
# 2. Сезонный порядок Q = 1, P = 3.

# %%
ts_diff = np.diff(ts, n = 1)
ts_diff = np.diff(ts_diff, n = 48)

# %%
fig, axs = plt.subplots(3, 2, figsize = (11,11))
axs[0, 0].remove()
axs[0, 1].remove()

gs = axs[0, 0].get_gridspec()
axbig = fig.add_subplot(gs[0, :2])
axbig.plot(ts_diff[:500])
axbig.set_title('Time series')

smt.graphics.plot_acf(ts_diff, lags=300, ax=axs[1,0], alpha=0.05)
smt.graphics.plot_pacf(ts_diff, lags=300, ax=axs[2,0], alpha=0.05)

smt.graphics.plot_acf(ts_diff, lags=50, ax=axs[1,1], alpha=0.05)
smt.graphics.plot_pacf(ts_diff, lags=50, ax=axs[2,1], alpha=0.05)
plt.show()

# %% [markdown]
# Выводы:
# 1. p = 4.
# 2. q = 9.

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
# order=(p, d, q),
# seasonal_order=(P, D, Q, S)
model = SARIMAX(ts, order=(4, 1, 9), seasonal_order=(3, 1, 1, 48))

results = model.fit()

results.summary()
# Out:
# C:\Users\Nikita\anaconda3\envs\DL\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  700
# Model:             SARIMAX(4, 1, 9)x(3, 1, [1], 48)   Log Likelihood                -575.878
# Date:                              Fri, 20 Oct 2023   AIC                           1187.756
# Time:                                      16:37:55   BIC                           1268.369
# Sample:                                           0   HQIC                          1219.022
#                                               - 700
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4841      0.839     -0.577      0.564      -2.128       1.160
# ar.L2          0.1002      0.294      0.341      0.733      -0.476       0.676
# ar.L3          0.2029      0.333      0.609      0.543      -0.450       0.856
# ar.L4          0.4486      0.384      1.169      0.243      -0.304       1.201
# ma.L1         -0.3754      0.836     -0.449      0.653      -2.014       1.264
# ma.L2         -0.5073      0.774     -0.655      0.512      -2.025       1.011
# ma.L3         -0.1320      0.443     -0.298      0.765      -1.000       0.736
# ma.L4         -0.2426      0.507     -0.479      0.632      -1.236       0.751
# ma.L5          0.3611      0.353      1.024      0.306      -0.330       1.052
# ma.L6          0.0544      0.059      0.919      0.358      -0.062       0.170
# ma.L7          0.0609      0.083      0.735      0.462      -0.101       0.223
# ma.L8         -0.1052      0.057     -1.845      0.065      -0.217       0.007
# ma.L9         -0.0329      0.100     -0.330      0.741      -0.228       0.163
# ar.S.L48      -0.0136      0.109     -0.125      0.901      -0.228       0.200
# ar.S.L96      -0.0047      0.084     -0.056      0.956      -0.170       0.161
# ar.S.L144      0.0276      0.071      0.389      0.697      -0.111       0.166
# ma.S.L48      -0.7373      0.109     -6.760      0.000      -0.951      -0.524
# sigma2         0.3232      0.019     17.146      0.000       0.286       0.360
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 1.24
# Prob(Q):                              0.86   Prob(JB):                         0.54
# Heteroskedasticity (H):               0.94   Skew:                             0.04
# Prob(H) (two-sided):                  0.64   Kurtosis:                         3.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
import pmdarima as pm

# %%
model1 = pm.auto_arima(
    y = ts,
    seasonal=True,
    m=48,
    start_p = 1, max_p = 9,
    start_d = 1, max_d = 1,
    start_q = 2, max_q = 11,
    start_P = 1, max_P = 5,
    start_D = 1, max_D = 1,
    start_Q = 1, max_Q = 3,
    trace=True,
    error_action='ignore',
    # suppress_warnings=True
)

print(model1.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,2)(1,0,1)[48] intercept   : AIC=inf, Time=9.99 sec
#  ARIMA(0,1,0)(0,0,0)[48] intercept   : AIC=1545.466, Time=0.05 sec
#  ARIMA(1,1,0)(1,0,0)[48] intercept   : AIC=1409.903, Time=1.87 sec
#  ARIMA(0,1,1)(0,0,1)[48] intercept   : AIC=1417.258, Time=2.04 sec
#  ARIMA(0,1,0)(0,0,0)[48]             : AIC=1543.583, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[48] intercept   : AIC=1434.566, Time=0.06 sec
#  ARIMA(1,1,0)(2,0,0)[48] intercept   : AIC=1396.421, Time=21.18 sec
#  ARIMA(1,1,0)(3,0,0)[48] intercept   : AIC=inf, Time=50.29 sec
#  ARIMA(1,1,0)(2,0,1)[48] intercept   : AIC=inf, Time=112.96 sec
#  ARIMA(1,1,0)(1,0,1)[48] intercept   : AIC=inf, Time=6.44 sec
#  ARIMA(1,1,0)(3,0,1)[48] intercept   : AIC=inf, Time=213.85 sec
#  ARIMA(0,1,0)(2,0,0)[48] intercept   : AIC=1533.084, Time=16.18 sec
#  ARIMA(2,1,0)(2,0,0)[48] intercept   : AIC=1372.135, Time=33.41 sec
#  ARIMA(2,1,0)(1,0,0)[48] intercept   : AIC=1396.667, Time=2.78 sec
#  ARIMA(2,1,0)(3,0,0)[48] intercept   : AIC=inf, Time=62.19 sec
#  ARIMA(2,1,0)(2,0,1)[48] intercept   : AIC=inf, Time=117.80 sec
#  ARIMA(2,1,0)(1,0,1)[48] intercept   : AIC=inf, Time=8.93 sec
#  ARIMA(2,1,0)(3,0,1)[48] intercept   : AIC=inf, Time=224.56 sec
# Exception ignored in: <function WeakSet.__init__.<locals>._remove at 0x0000024BB4B203A0>
# Traceback (most recent call last):
#   File "C:\Users\Nikita\anaconda3\envs\DL\lib\_weakrefset.py", line 40, in _remove
#     self = selfref()
# KeyboardInterrupt:
#
# KeyboardInterrupt

# %% [markdown]
# # Задание
# - Выбрать один из временных рядов из списка.(или любой другой временной ряд который вы захотите - главное, чтобы он не был слишком простым)
# - Визуализировать ACF и PACF.
# - Построить и выбрать лучшую AR, ARMA, SARIMA модели.(для последней можно использовать auto arima)
# - К лучшей модели из предыдущих попробовать добавить GARCH.
# - Проанализирвоать результаты работы моделей (Анализ ошибки) для каждой из моделей
#   - Графики остатков + выводы
#   - Распределение остатков + выоды

# %%
DATA_PATH = "https://raw.githubusercontent.com/intsystems/MathematicalForecastingMethods/main/data/AirPassengers.csv"
# DATA_PATH = "https://raw.githubusercontent.com/intsystems/MathematicalForecastingMethods/main/data/Electric_Production.csv
# DATA_PATH = "https://raw.githubusercontent.com/intsystems/MathematicalForecastingMethods/main/data/accident_UK.csv
# DATA_PATH = "https://raw.githubusercontent.com/intsystems/MathematicalForecastingMethods/main/data/shampoo_sales.csv

# %%
ts = pd.read_csv(DATA_PATH)

# %%
ts.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
fig, axs = plt.subplots(2, 2, figsize = (11,11))
axs[0, 0].remove()
axs[0, 1].remove()

gs = axs[0, 0].get_gridspec()
axbig = fig.add_subplot(gs[0, :2])
axbig.plot(ts["#Passengers"])
axbig.set_title('Time series')

smt.graphics.plot_acf(ts["#Passengers"], ax=axs[1,0], alpha=0.05)
smt.graphics.plot_pacf(ts["#Passengers"], ax=axs[1,1], alpha=0.05)

plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposed = seasonal_decompose(ts["#Passengers"], period=12)
decomposed.plot()
plt.show()

# %% [markdown]
# Из графиков, $S = 12, P = 1, Q = 1$ и есть тренд, тогда возьмем $d = 1, D = 1$

# %%
ts_diff = np.diff(ts["#Passengers"], n = 1)
ts_diff = ts_diff[12:] - ts_diff[:-12]

# %%
fig, axs = plt.subplots(2, 2, figsize = (11,11))
axs[0, 0].remove()
axs[0, 1].remove()

gs = axs[0, 0].get_gridspec()
axbig = fig.add_subplot(gs[0, :2])
axbig.plot(ts_diff)
axbig.set_title('Time series')

smt.graphics.plot_acf(ts_diff, lags=64, ax=axs[1,0], alpha=0.05)
smt.graphics.plot_pacf(ts_diff, lags=64, ax=axs[1,1], alpha=0.05)

plt.show()

# %% [markdown]
# Кажется не удалось полностью избавится от сезонности, попробуем еще раз продифференцировать

# %%
ts_diff2 = ts_diff[12:] - ts_diff[:-12]

# %%
fig, axs = plt.subplots(2, 2, figsize = (11,11))
axs[0, 0].remove()
axs[0, 1].remove()

gs = axs[0, 0].get_gridspec()
axbig = fig.add_subplot(gs[0, :2])
axbig.plot(ts_diff2)
axbig.set_title('Time series')

smt.graphics.plot_acf(ts_diff2, lags=58, ax=axs[1,0], alpha=0.05)
smt.graphics.plot_pacf(ts_diff2, lags=58, ax=axs[1,1], alpha=0.05)

plt.show()

# %% [markdown]
# Не очевидно нужно ли дифференцировать второй раз, будем проверять в SARIMAX с auto_arima. Для остальных моделей возьмем $q = 12\pm2$, $p=12\pm2$

# %% [markdown]
# #### AR и ARMA

# %%
ts["#Passengers"]
# Out:
# 0      112
# 1      118
# 2      132
# 3      129
# 4      121
#       ...
# 139    606
# 140    508
# 141    461
# 142    390
# 143    432
# Name: #Passengers, Length: 144, dtype: int64

# %%
from tqdm.auto import tqdm
import warnings
warnings.filterwarnings("ignore")

ar_AICs = {}
arma_AICs = {}

for p in tqdm([10, 11, 12, 13, 14], colour="#118820"):
    for q in tqdm([10, 11, 12, 13, 14], colour="#803220"):
        arma_res = SARIMAX(ts["#Passengers"], order=(p, 0, q), seasonal_order=(0, 0, 0, 12)).fit()
        arma_AICs.update({f"p = {p}, q = {q}": arma_res.aic})
        
    ar_res = SARIMAX(ts["#Passengers"], order=(p, 0, 0), seasonal_order=(0, 0, 0, 12)).fit()
    ar_AICs.update({f"p = {p}": arma_res.aic})

print("AR results:")
[print(f"  Params: {key}   AIC: {val}") for key, val in ar_AICs.items()]
print(f"AR best AIC: {min(ar_AICs.values())}")
print("\nARMA results:")
[print(f"  Params: {key}   AIC: {val}") for key, val in arma_AICs.items()]
print(f"ARMA best AIC: {min(arma_AICs.values())}")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# AR results:
#   Params: p = 10, q = 14   AIC: 1304.8151383518593
#   Params: p = 11, q = 14   AIC: 1245.8985778126503
#   Params: p = 12, q = 14   AIC: 1183.8362217735555
#   Params: p = 13, q = 14   AIC: 1209.7359489800683
#   Params: p = 14, q = 14   AIC: 1198.5384603798925
# AR best AIC: 1183.8362217735555
#
# ARMA results:
#   Params: p = 10, q = 10   AIC: 1317.1668063900402
#   Params: p = 10, q = 11   AIC: 1319.1777459707678
#   Params: p = 10, q = 12   AIC: 1315.1272348317161
#   Params: p = 10, q = 13   AIC: 1299.5110648167035
#   Params: p = 10, q = 14   AIC: 1304.8151383518593
#   Params: p = 11, q = 10   AIC: 1206.1944923961369
#   Params: p = 11, q = 11   AIC: 1189.0933579291275
#   Params: p = 11, q = 12   AIC: 1235.6500579805897
#   Params: p = 11, q = 13   AIC: 1222.0112616270767
#   Params: p = 11, q = 14   AIC: 1245.8985778126503
#   Params: p = 12, q = 10   AIC: 1185.4391539456687
#   Params: p = 12, q = 11   AIC: 1183.3326260807276
#   Params: p = 12, q = 12   AIC: 1180.0935355040383
#   Params: p = 12, q = 13   AIC: 1184.1321507641867
#   Params: p = 12, q = 14   AIC: 1183.8362217735555
#   Params: p = 13, q = 10   AIC: 1190.5744507727638
#   Params: p = 13, q = 11   AIC: 1182.8012423631803
#   Params: p = 13, q = 12   AIC: 1184.575821069564
#   Params: p = 13, q = 13   AIC: 1213.0912974393807
#   Params: p = 13, q = 14   AIC: 1209.7359489800683
#   Params: p = 14, q = 10   AIC: 1186.180361080238
#   Params: p = 14, q = 11   AIC: 1181.7016877764984
#   Params: p = 14, q = 12   AIC: 1184.210879066286
#   Params: p = 14, q = 13   AIC: 1189.090500771581
#   Params: p = 14, q = 14   AIC: 1198.5384603798925
# ARMA best AIC: 1180.0935355040383

# %%
best_ar = SARIMAX(ts["#Passengers"], order=(12, 0, 0), seasonal_order=(0, 0, 0, 12)).fit()
best_arma = SARIMAX(ts["#Passengers"], order=(12, 0, 12), seasonal_order=(0, 0, 0, 12)).fit()

# %%
preds_ar = best_ar.predict()
preds_arma = best_arma.predict()

residuals_ar = ts["#Passengers"].values - preds_ar
residuals_arma = ts["#Passengers"].values - preds_arma

# %% [markdown]
# #### SARIMAX

# %%
from copy import deepcopy
ts_for_StatsForecast = deepcopy(ts)
ts_for_StatsForecast.rename(columns={"#Passengers": "y", "Month":"ds"}, inplace=True)
ts_for_StatsForecast["unique_id"] = ["1"] * len(ts_for_StatsForecast)

# %%
from statsforecast.models import AutoARIMA 
from statsforecast import StatsForecast

sarimax = AutoARIMA(
    max_d = 1, max_D = 2,
    max_p = 14,
    max_q = 14, 
    max_P = 1, 
    max_Q = 1, 
    max_order = 100,  
    season_length = 12,
    ic = 'aic',
    trace=True,
    stepwise = False,
)

sf = StatsForecast(n_jobs=14,
            models = [sarimax],
            freq="M",
            verbose=False)
#ts["#Passengers"].values
sf.fit(ts_for_StatsForecast)
# Out:
# Best model: ARIMA(0,1,4)(1,1,0)[12]
# StatsForecast(models=[AutoARIMA])

# %%
sf.fitted_[0][0].model_["aic"]
# Out:
# 1019.8481840342829

# %%
preds_sarimax = sf.fitted_[0][0].predict_in_sample()["fitted"]

# %%
residuals_sarimax = ts_for_StatsForecast["y"] - preds_sarimax

# %%
fig, axs = plt.subplots(3, 1, figsize = (12,18))

axs[0].plot(ts["#Passengers"], label="original data", alpha=0.6, lw=2, color=sns.color_palette()[3])
axs[0].plot(preds_sarimax, label="SARIMAX", alpha=0.6, lw=2)
axs[0].plot(preds_ar, label="AR", alpha=0.6, lw=2)
axs[0].plot(preds_arma, label="ARMA", alpha=0.6, lw=2)

axs[0].legend(shadow=True, fontsize=16)
axs[0].set_title('Predictions', fontsize=18)


axs[1].plot(residuals_sarimax, label="SARIMAX", alpha=0.6, lw=2)
axs[1].plot(residuals_ar, label="AR", alpha=0.6, lw=2)
axs[1].plot(residuals_arma, label="ARMA", alpha=0.6, lw=2)

axs[1].set_title('Residuals', fontsize=18)
axs[1].legend(shadow=True, fontsize=16)

all_res = pd.DataFrame({"SARIMAX": residuals_sarimax,
                        "AR": residuals_ar,
                        "ARMA": residuals_arma})
sns.kdeplot(data=all_res, ax=axs[2], legend=False)

axs[2].set_title('Residuals', fontsize=18)
axs[2].legend(labels=["SARIMAX", "AR", "ARMA"], shadow=True, fontsize=16)

plt.show()

# %% [markdown]
# Выводы:
# - ARMA и SARIMAX на глаз не отличимы, хотя SARIMAX после долгого перебора параметров дает ожидаемо лучший скор.
# - AR недостаточно для выбранного ряда, распределение ошибок сильно отличается от нормального и явно смещено относительно нуля.
# - AIC слабо коррелирует с оценкой "на глаз": скоры AR и ARMA почти идентичны, хотя график остатков для AR гораздо более шумный, тогда как превосходство SARIMAX над ARMA в 20% практически не заметно

# %% [markdown]
# #### GARCH

# %%
fig, axs = plt.subplots(2, 2, figsize = (11,11))
axs[0, 0].remove()
axs[0, 1].remove()

gs = axs[0, 0].get_gridspec()
axbig = fig.add_subplot(gs[0, :2])
axbig.plot(residuals_sarimax)
axbig.set_title('Time series')

smt.graphics.plot_acf(residuals_sarimax, lags=71, ax=axs[1,0], alpha=0.05)
smt.graphics.plot_pacf(residuals_sarimax, lags=71, ax=axs[1,1], alpha=0.05)

plt.show()

# %% [markdown]
# Попробуем $p=1$, $q=1$

# %%
from arch import arch_model

garch = arch_model(residuals_sarimax, p = 1, q = 1, vol = "GARCH")
garch_res = garch.fit(last_obs = 1, update_freq = 1, show_warning=False)
# Out:
# Iteration:      1,   Func. Count:      4,   Neg. LLF: nan
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: nan
#             Iterations: 1
#             Function evaluations: 4
#             Gradient evaluations: 1

# %%
preds_garch_sarimax = garch_res.forecast().residual_variance.values[:, 0]

# %%
fig, axs = plt.subplots(2, 1, figsize = (12, 8))

axs[0].plot(ts["#Passengers"], label="original data", alpha=0.6, lw=2, color=sns.color_palette()[0])
axs[0].plot(preds_sarimax, label="SARIMAX predictions", alpha=0.6, lw=2,
             color=sns.color_palette()[1])
axs[0].fill_between(range(0, 144), 
                    preds_sarimax - preds_garch_sarimax, 
                    preds_sarimax + preds_garch_sarimax, 
                    label="SARIMAX+GARCH confint", 
                    alpha=0.4, ls="--", lw=2,
                    color=sns.color_palette()[1],
                    edgecolor = "black")

axs[0].legend(shadow=True, fontsize=16)
axs[0].set_title('Predictions', fontsize=18)


axs[1].plot(residuals_sarimax, label="SARIMAX", alpha=0.6, lw=2)
axs[1].fill_between(range(0, 144), 
                    -preds_garch_sarimax, 
                    preds_garch_sarimax, 
                    label="SARIMAX+GARCH confint", 
                    alpha=0.3, ls="--", lw=2, 
                    color=sns.color_palette()[1])


axs[1].set_title('Residuals', fontsize=18)
axs[1].legend(shadow=True, fontsize=16, loc="upper left")

plt.show()

# %% [markdown]
# Что-то не очень работает, по хорошему все таки предсказывать эту дисперсию на новых данных, но ряд итак довольно маленький, делить его на части не очень хочется, да и в задании явно не сказано.
